# %%
# %load_ext autoreload
# %autoreload 2

# %%
#==========================================================
# Load Packages 
#==========================================================

from dig.threedgraph.dataset import QM93D                           # Dataset utilities for 3D molecular graphs (QM9 with 3D coordinates)
from torch_geometric.datasets import QM9       # Loading the QM9 dataset from Torch-Geometric

from torch_geometric.nn import GCNConv, global_mean_pool, GINConv   # Graph Neural Network layers and pooling operations from PyTorch Geometric
from torch_geometric.loader import DataLoader                       # DataLoader to batch and shuffle molecular graph data
from torch.optim import Adam                                        # Optimizer (Adam) and learning rate scheduler (StepLR)
from torch.optim.lr_scheduler import StepLR                         # Progress bar for training/evaluation loops
from tqdm import tqdm                                               # Unit conversion constants (Hartree, eV, Bohr, Angstrom) from ASE
from ase.units import Hartree, eV, Bohr, Ang                        # TensorBoard writer for tracking metrics and visualizing training progress
from torch.utils.tensorboard import SummaryWriter                   # TensorBoard writer for tracking metrics and visualizing training progress
from dig.threedgraph.method import SphereNet    
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import sys
sys.path.append('/project/IZZY/MolRepres/Methods/')
from model import SphereNet_model                      # 3D GNN model implementation (SphereNet) from DIG (Deep Graph Library for 3D Graphs)

# %%
#==========================================================
# GPU Device
#==========================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # This line checks if a CUDA-enabled GPU is available. If yes, computations will be performed on the GPU for faster training. Otherwise, it falls back to using the CPU.
# Print which device is being used 
print("Using device:", device)
# Out:
# Using device: cuda

# %%
#==============================================================
# Load dataset and split
#==============================================================

# Load the QM9 dataset 
dataset = QM9(root='data/QM9')

# Count how many molecular graphs are in the dataset
num_mols = len(dataset)
print(f"Total QM9 molecules: {num_mols}")

# Define the desired split sizes for training, validation, and testing
train_size, valid_size = 110000, 10000
# Ensure the sum of train and validation sizes does not exceed dataset size
assert train_size + valid_size < num_mols, "Split sizes too large for dataset"

# Randomly shuffle all molecule indices
perm = torch.randperm(num_mols, generator=torch.Generator().manual_seed(42))

# Use the shuffled indices to create non-overlapping subsets
train_idx = perm[:train_size]
valid_idx = perm[train_size:train_size+valid_size]
test_idx  = perm[train_size+valid_size:]

# Build subsets based on the index splits
train_dataset = dataset[train_idx]
valid_dataset = dataset[valid_idx]
test_dataset  = dataset[test_idx]
# Out:
# Total QM9 molecules: 130831

# %%
#======================================================================
# Define the QM9 Targets
#======================================================================
PROPERTY_NAMES = [
    'μ (D)', 'α (Ang³)', 'ε_HOMO (eV)', 'ε_LUMO (eV)', 'Δε (eV)', '⟨R²⟩ (Ang²)',
    'ZPVE (eV)', 'U₀ (eV)', 'U (eV)', 'H (eV)', 'G (eV)', 'c_v', 'U₀_atom',
    'U_atom', 'H_atom', 'G_atom', 'A (GHz)', 'B (GHz)', 'C (GHz)'
] 

# ======================================================================
# QM9 Unit Conversion Factors
# ======================================================================
def get_qm9_conversions_tensor(device):
    return torch.tensor([
        1.0, Bohr**3 / Ang**3, Hartree / eV, Hartree / eV, Hartree / eV,
        Bohr**2 / Ang**2, Hartree / eV, Hartree / eV, Hartree / eV,
        Hartree / eV, Hartree / eV, 1.0, 1.0, Hartree / eV,
        Hartree / eV, Hartree / eV, 1.0, 1.0, 1.0
    ], dtype=torch.float, device=device)

# %%
#========================================================================
# Normalize all QM9 targets
#========================================================================
y_raw_all = dataset.data.y.clone().cpu()
conversions_cpu = get_qm9_conversions_tensor('cpu')
y_conv_all = y_raw_all * conversions_cpu.unsqueeze(0)

norm_stats = {'mean': [], 'std': []}
y_norm_all = torch.zeros_like(y_conv_all)

for i in range(y_conv_all.shape[1]):
    train_y_cpu = y_conv_all[train_idx.cpu(), i]
    mean_i = float(train_y_cpu.mean().item())
    std_i = float(train_y_cpu.std().item()) if train_y_cpu.std().item() != 0 else 1.0
    y_norm_all[:, i] = (y_conv_all[:, i] - mean_i) / std_i
    norm_stats['mean'].append(mean_i)
    norm_stats['std'].append(std_i)

dataset.data.y = y_norm_all.to(torch.float)
print("Normalization complete for all targets.")
# Out:
# Normalization complete for all targets.
# /home/ismail/dig_envi/lib/python3.9/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)

# %%
#=================================================================================
# Training and Evaluation Funcitons
#=================================================================================

#--------------------------------------------------
# Train eopch
#--------------------------------------------------
def train_epoch(model, loader, optimizer, device):
    """

    Perform one epoch of training.

    Args: 
        model: PyTorch model
        loader:DataLoader for training data
        optimizer: optimizer (e.g, Adam)
        device: 'cpu' or 'cuda'

    Returns:
        Average training loss over the epoch

    """
    
    model.train() # set model to training mdoe (enables dropout, etc)
    total_loss = 0.0

    # Iterate over batches
    for batch in tqdm(loader, desc="Train", leave=False):
        batch = batch.to(device)                            # move batch to GPU 
        optimizer.zero_grad()                               # reset gradients
        pred = model(batch)                                 # forward pass -> predicted values         
        target = batch.y                                    # true normalized targets   
        # Compute Mean Squared Error (MSE) loss
        #print('========================================')
        #print(pred.shape)
        #print(target.shape)
        loss = F.mse_loss(pred, target)   

        # Backpropagation
        loss.backward()
        optimizer.step()                                    # update mdoel parameters
        total_loss += loss.item()                           # accumulate loss

    # Return average loss over all batches
    return total_loss / len(loader)


#--------------------------------------------------------
# Evaluate model
#--------------------------------------------------------
@torch.no_grad() # disables gradient computation for efficiency 
def evaluate(model, loader, device, norm_means, norm_stds):
    """

    Evaluate model performence on validation or test set.

    Args:
        model: PyTorch model
        loader: DataLoader for evaluation data
        device: 'cpu' or 'cuda'
        norm_mean: mean used for target normalization
        norm_std: std used for target normalization

    Returns:
        Mean Absolute Error (MAE) in real units
    """
    
    model.eval()
    preds, targets = [], []
    for batch in tqdm(loader, desc="Eval", leave=False):
        batch = batch.to(device)
        out = model(batch).detach().cpu()    # shape [B, 19]
        t = batch.y.detach().cpu()           # shape [B, 19]
        preds.append(out)
        targets.append(t)             
    preds = torch.cat(preds, dim=0)
    targets = torch.cat(targets, dim=0)

    maes = []
    for i in range(len(norm_means)):
        preds_den = preds[:, i] * norm_stds[i] + norm_means[i]
        targets_den = targets[:, i]* norm_stds[i] + norm_means[i]
        mae = torch.mean(torch.abs(preds_den - targets_den)).item()
        maes.append(mae)
    return maes

# %%
#==============================================================================================
# Trainig Loop
#==============================================================================================

def main():
    #------------------------------
    # Hyperparameters
    #------------------------------
    epochs = 200                           # number of training epochs
    batch_size = 128                       # batch size for training
    vt_batch_size = 256                    # batch size for validation
    lr = 1e-5                              # learning rate
    lr_decay_step = 50                     # steps after which LR is decayed
    lr_decay_factor = 0.5                  # factor to decay learning rate
    weight_decay = 1e-4                     # L2 regularization
    save_dir = 'checkpoints_gcn_single'    # directory to save model checkpoints 
    log_dir = 'logs_gcn_single'            # TensorBoard logs directory

    #Create directories if they don't exist
    os.makedirs(save_dir, exist_ok=True)
    os.makedirs(log_dir, exist_ok=True)

    # TensorBoard write for visualization of metrics
    writer = SummaryWriter(log_dir=log_dir)

    #-----------------------------
    # Dataloaders 
    #-----------------------------

    # Shuffled batches for training; sequential batches for validation/testing
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(valid_dataset, batch_size=vt_batch_size, shuffle=False)
    test_loader  = DataLoader(test_dataset, batch_size=vt_batch_size, shuffle=False)

    #----------------------------------------
    # Model
    #----------------------------------------
    # GCN model
    model = SphereNet_model().to(device)   # GCN model uncommented to use it 

    #----------------------------------------
    # Optimizer and Scheduler
    #----------------------------------------
    optimizer = Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = StepLR(optimizer, step_size=lr_decay_step, gamma=lr_decay_factor)

    # Track best validation/test performance

    best_val = [float('inf')] * len(PROPERTY_NAMES)
    best_test = [float('inf')] * len(PROPERTY_NAMES)

    # Print total number of trainabel parameters and target property
    print("#params:", sum(p.numel() for p in model.parameters()))
    print("Training for all 19 targets") 
    
    #--------------------------------------------
    # Training Loop
    #--------------------------------------------
    for epoch in range(1, epochs + 1):
        print(f"\n=== Epoch {epoch} ===")

        #Train for one epoch
        train_loss = train_epoch(model, train_loader, optimizer, device)

        # Evaluate on validation and test sets (MAE in original units)
        val_mae = evaluate(model, val_loader, device, norm_stats['mean'], norm_stats['std'])
        test_mae = evaluate(model, test_loader, device, norm_stats['mean'], norm_stats['std'])

        # Print epoch metrics
        print(f"Train loss (MSE): {train_loss:.6f}")
        for i, prop in enumerate(PROPERTY_NAMES):
            print(f"  {prop:15s} | Val MAE: {val_mae[i]:.6f} | Test MAE: {test_mae[i]:.6f}")
            writer.add_scalar(f'val_mae/{prop}', val_mae[i], epoch)
            writer.add_scalar(f'test_mae/{prop}', test_mae[i], epoch)
        #---------------------------------------------
        # Save checkpoint if validation improves
        #---------------------------------------------

        for i in range(len(PROPERTY_NAMES)):
            if val_mae[i] < best_val[i]:
                best_val[i] = val_mae[i]
                best_test[i] = test_mae[i]
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'best_val': best_val,
                }, os.path.join(save_dir, f'best_model_target{i}.pt'))
                print(f"Saved best model for target {PROPERTY_NAMES[i]}.")

            
        # Update learning rate according to scheduler
        scheduler.step()
    # Close TensorBoard writer
    writer.close()
    print("\nFinished training.")
    print("Best validation and test MAEs per property:")
    for prop, v, t in zip(PROPERTY_NAMES, best_val, best_test):
        print(f"  {prop:15s} | Best validation MAE: {v:.6f} | Test MAE at best val: {t:.6f}")

    
    #print("Best validation MAE:", best_val)
    #print("Test MAE at best val:", best_test)

# Run the training loop
if __name__ == "__main__":
    main()
# Out:
# #params: 1913158
# Training for all 19 targets
#
# === Epoch 1 ===
# Train loss (MSE): 0.938104
#   μ (D)           | Val MAE: 0.815158 | Test MAE: 0.817679
#   α (Ang³)        | Val MAE: 0.354675 | Test MAE: 0.343897
#   ε_HOMO (eV)     | Val MAE: 6.525274 | Test MAE: 6.586985
#   ε_LUMO (eV)     | Val MAE: 10.301051 | Test MAE: 10.365075
#   Δε (eV)         | Val MAE: 12.792475 | Test MAE: 12.743494
#   ⟨R²⟩ (Ang²)     | Val MAE: 27.179449 | Test MAE: 26.573069
#   ZPVE (eV)       | Val MAE: 3.247070 | Test MAE: 3.161899
#   U₀ (eV)         | Val MAE: 8305.260742 | Test MAE: 8016.729004
#   U (eV)          | Val MAE: 7709.054199 | Test MAE: 7470.942871
#   H (eV)          | Val MAE: 8227.756836 | Test MAE: 7941.742188
#   G (eV)          | Val MAE: 7874.948730 | Test MAE: 7610.522461
#   c_v             | Val MAE: 1.200644 | Test MAE: 1.171582
#   U₀_atom         | Val MAE: 2.303463 | Test MAE: 2.248792
#   U_atom          | Val MAE: 55.590195 | Test MAE: 53.881042
#   H_atom          | Val MAE: 52.864269 | Test MAE: 51.444962
#   G_atom          | Val MAE: 51.563656 | Test MAE: 49.988834
#   A (GHz)         | Val MAE: 130.299225 | Test MAE: 128.311829
#   B (GHz)         | Val MAE: 0.225202 | Test MAE: 0.223560
#   C (GHz)         | Val MAE: 0.158041 | Test MAE: 0.155657
# Saved best model for target μ (D).
# Saved best model for target α (Ang³).
# Saved best model for target ε_HOMO (eV).
# Saved best model for target ε_LUMO (eV).
# Saved best model for target Δε (eV).
# Saved best model for target ⟨R²⟩ (Ang²).
# Saved best model for target ZPVE (eV).
# Saved best model for target U₀ (eV).
# Saved best model for target U (eV).
# Saved best model for target H (eV).
# Saved best model for target G (eV).
# Saved best model for target c_v.
# Saved best model for target U₀_atom.
# Saved best model for target U_atom.
# Saved best model for target H_atom.
# Saved best model for target G_atom.
# Saved best model for target A (GHz).
# Saved best model for target B (GHz).
# Saved best model for target C (GHz).
#
# === Epoch 2 ===
# Train loss (MSE): 0.266350
#   μ (D)           | Val MAE: 0.796825 | Test MAE: 0.797907
#   α (Ang³)        | Val MAE: 0.215413 | Test MAE: 0.211970
#   ε_HOMO (eV)     | Val MAE: 6.290360 | Test MAE: 6.343872
#   ε_LUMO (eV)     | Val MAE: 8.559400 | Test MAE: 8.633581
#   Δε (eV)         | Val MAE: 10.945794 | Test MAE: 10.944828
#   ⟨R²⟩ (Ang²)     | Val MAE: 17.354422 | Test MAE: 17.233669
#   ZPVE (eV)       | Val MAE: 1.914799 | Test MAE: 1.888161
#   U₀ (eV)         | Val MAE: 6166.600586 | Test MAE: 6032.377930
#   U (eV)          | Val MAE: 7742.651367 | Test MAE: 7625.430664
#   H (eV)          | Val MAE: 7708.288086 | Test MAE: 7614.078613
#   G (eV)          | Val MAE: 5146.896484 | Test MAE: 4990.844727
#   c_v             | Val MAE: 0.620519 | Test MAE: 0.599983
#   U₀_atom         | Val MAE: 1.122267 | Test MAE: 1.099582
#   U_atom          | Val MAE: 29.428499 | Test MAE: 29.040911
#   H_atom          | Val MAE: 28.654034 | Test MAE: 27.658787
#   G_atom          | Val MAE: 29.631315 | Test MAE: 28.874672
#   A (GHz)         | Val MAE: 134.896576 | Test MAE: 131.333496
#   B (GHz)         | Val MAE: 0.191403 | Test MAE: 0.187779
#   C (GHz)         | Val MAE: 0.142055 | Test MAE: 0.140769
# Saved best model for target μ (D).
# Saved best model for target α (Ang³).
# Saved best model for target ε_HOMO (eV).
# Saved best model for target ε_LUMO (eV).
# Saved best model for target Δε (eV).
# Saved best model for target ⟨R²⟩ (Ang²).
# Saved best model for target ZPVE (eV).
# Saved best model for target U₀ (eV).
# Saved best model for target H (eV).
# Saved best model for target G (eV).
# Saved best model for target c_v.
# Saved best model for target U₀_atom.
# Saved best model for target U_atom.
# Saved best model for target H_atom.
# Saved best model for target G_atom.
# Saved best model for target B (GHz).
# Saved best model for target C (GHz).
#
# === Epoch 3 ===
# Train loss (MSE): 0.223406
#   μ (D)           | Val MAE: 0.666865 | Test MAE: 0.660828
#   α (Ang³)        | Val MAE: 0.143474 | Test MAE: 0.143118
#   ε_HOMO (eV)     | Val MAE: 7.288217 | Test MAE: 7.282644
#   ε_LUMO (eV)     | Val MAE: 8.108717 | Test MAE: 8.174609
#   Δε (eV)         | Val MAE: 9.678644 | Test MAE: 9.647027
#   ⟨R²⟩ (Ang²)     | Val MAE: 10.375416 | Test MAE: 10.193443
#   ZPVE (eV)       | Val MAE: 1.693425 | Test MAE: 1.687298
#   U₀ (eV)         | Val MAE: 3203.881104 | Test MAE: 3112.530029
#   U (eV)          | Val MAE: 2915.510498 | Test MAE: 2846.197998
#   H (eV)          | Val MAE: 3514.060791 | Test MAE: 3401.432861
#   G (eV)          | Val MAE: 2866.648438 | Test MAE: 2787.610107
#   c_v             | Val MAE: 0.370628 | Test MAE: 0.363439
#   U₀_atom         | Val MAE: 0.865978 | Test MAE: 0.847408
#   U_atom          | Val MAE: 20.387247 | Test MAE: 20.036692
#   H_atom          | Val MAE: 22.720844 | Test MAE: 22.479181
#   G_atom          | Val MAE: 19.984774 | Test MAE: 19.437082
#   A (GHz)         | Val MAE: 83.544098 | Test MAE: 82.177322
#   B (GHz)         | Val MAE: 0.175295 | Test MAE: 0.170240
#   C (GHz)         | Val MAE: 0.091576 | Test MAE: 0.090994
# Saved best model for target μ (D).
# Saved best model for target α (Ang³).
# Saved best model for target ε_LUMO (eV).
# Saved best model for target Δε (eV).
# Saved best model for target ⟨R²⟩ (Ang²).
# Saved best model for target ZPVE (eV).
# Saved best model for target U₀ (eV).
# Saved best model for target U (eV).
# Saved best model for target H (eV).
# Saved best model for target G (eV).
# Saved best model for target c_v.
# Saved best model for target U₀_atom.
# Saved best model for target U_atom.
# Saved best model for target H_atom.
# Saved best model for target G_atom.
# Saved best model for target A (GHz).
# Saved best model for target B (GHz).
# Saved best model for target C (GHz).
#
# === Epoch 4 ===
# Train loss (MSE): 3.800569
#   μ (D)           | Val MAE: 0.942735 | Test MAE: 0.956053
#   α (Ang³)        | Val MAE: 0.514599 | Test MAE: 0.499825
#   ε_HOMO (eV)     | Val MAE: 9.308908 | Test MAE: 9.209041
#   ε_LUMO (eV)     | Val MAE: 16.932869 | Test MAE: 17.057077
#   Δε (eV)         | Val MAE: 18.962168 | Test MAE: 18.996836
#   ⟨R²⟩ (Ang²)     | Val MAE: 45.359779 | Test MAE: 44.955982
#   ZPVE (eV)       | Val MAE: 5.573458 | Test MAE: 5.460733
#   U₀ (eV)         | Val MAE: 11587.470703 | Test MAE: 11361.170898
#   U (eV)          | Val MAE: 12394.108398 | Test MAE: 12119.422852
#   H (eV)          | Val MAE: 11270.577148 | Test MAE: 10997.103516
#   G (eV)          | Val MAE: 12066.232422 | Test MAE: 11715.772461
#   c_v             | Val MAE: 1.521411 | Test MAE: 1.481183
#   U₀_atom         | Val MAE: 3.260695 | Test MAE: 3.166093
#   U_atom          | Val MAE: 88.238518 | Test MAE: 85.219727
#   H_atom          | Val MAE: 87.035660 | Test MAE: 85.048737
#   G_atom          | Val MAE: 82.868874 | Test MAE: 80.820473
#   A (GHz)         | Val MAE: 284.153137 | Test MAE: 282.171783
#   B (GHz)         | Val MAE: 0.332853 | Test MAE: 0.330012
#   C (GHz)         | Val MAE: 0.236636 | Test MAE: 0.234813
#
# === Epoch 5 ===
# Train loss (MSE): 0.402150
#   μ (D)           | Val MAE: 0.826840 | Test MAE: 0.835418
#   α (Ang³)        | Val MAE: 0.451621 | Test MAE: 0.443579
#   ε_HOMO (eV)     | Val MAE: 7.685028 | Test MAE: 7.625090
#   ε_LUMO (eV)     | Val MAE: 11.849793 | Test MAE: 11.943705
#   Δε (eV)         | Val MAE: 14.221937 | Test MAE: 14.312845
#   ⟨R²⟩ (Ang²)     | Val MAE: 34.505920 | Test MAE: 33.781761
#   ZPVE (eV)       | Val MAE: 5.928617 | Test MAE: 5.933970
#   U₀ (eV)         | Val MAE: 9630.207031 | Test MAE: 9415.864258
#   U (eV)          | Val MAE: 9772.784180 | Test MAE: 9474.877930
#   H (eV)          | Val MAE: 10345.450195 | Test MAE: 10191.346680
#   G (eV)          | Val MAE: 10403.614258 | Test MAE: 10124.863281
#   c_v             | Val MAE: 1.265135 | Test MAE: 1.237939
#   U₀_atom         | Val MAE: 2.872832 | Test MAE: 2.819572
#   U_atom          | Val MAE: 82.711266 | Test MAE: 81.838509
#   H_atom          | Val MAE: 69.855064 | Test MAE: 68.944687
#   G_atom          | Val MAE: 67.223991 | Test MAE: 65.422432
#   A (GHz)         | Val MAE: 143.024521 | Test MAE: 140.826462
#   B (GHz)         | Val MAE: 0.355346 | Test MAE: 0.351589
#   C (GHz)         | Val MAE: 0.175904 | Test MAE: 0.172675
#
# === Epoch 6 ===
# Train loss (MSE): 0.319932
#   μ (D)           | Val MAE: 0.795065 | Test MAE: 0.797046
#   α (Ang³)        | Val MAE: 0.352155 | Test MAE: 0.349883
#   ε_HOMO (eV)     | Val MAE: 6.921878 | Test MAE: 6.986920
#   ε_LUMO (eV)     | Val MAE: 12.357026 | Test MAE: 12.470397
#   Δε (eV)         | Val MAE: 12.538263 | Test MAE: 12.553822
#   ⟨R²⟩ (Ang²)     | Val MAE: 23.413597 | Test MAE: 22.910589
#   ZPVE (eV)       | Val MAE: 6.582381 | Test MAE: 6.571417
#   U₀ (eV)         | Val MAE: 11459.113281 | Test MAE: 11426.710938
#   U (eV)          | Val MAE: 8036.586426 | Test MAE: 7956.692383
#   H (eV)          | Val MAE: 12329.984375 | Test MAE: 12284.041016
#   G (eV)          | Val MAE: 7918.272949 | Test MAE: 7737.060059
#   c_v             | Val MAE: 1.003632 | Test MAE: 0.993134
#   U₀_atom         | Val MAE: 2.866745 | Test MAE: 2.846988
#   U_atom          | Val MAE: 93.814018 | Test MAE: 92.876740
#   H_atom          | Val MAE: 87.002502 | Test MAE: 87.199722
#   G_atom          | Val MAE: 46.818050 | Test MAE: 46.043907
#   A (GHz)         | Val MAE: 128.425919 | Test MAE: 125.002274
#   B (GHz)         | Val MAE: 0.489910 | Test MAE: 0.483539
#   C (GHz)         | Val MAE: 0.212143 | Test MAE: 0.211812
#
# === Epoch 7 ===
# Train:  87%|████████▋ | 750/860 [01:44<00:15,  7.26it/s]
